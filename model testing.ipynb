# %%
import csv
import math
import matplotlib.pyplot as plt
import numpy
import random
import sklearn
import string
from collections import defaultdict
from nltk.stem.porter import *
from sklearn import linear_model
from sklearn.manifold import TSNE
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords

# %%
# convert csv to list of dicts
with open('final_df.csv') as f:
    data = [{k: v for k, v in row.items()} for row in csv.DictReader(f, skipinitialspace=True)]

# %%
data[0]
# Out:
# {'uid_x': '255938',
#  'profile': 'DesolatePsyche',
#  'anime_uid': '34096',
#  'text': 'First things first My reviews system is explained on a blog entry Which can be found through my profile   Im going to keep this review more of a opinion of Gintamas overall and then this season specific  Anyhow What I have always loved regarding Gintama is its content of everything I love the comedy its absurd random can be vile dirty sweet anyhow everything Have laughed countless times in this franchise Also the humor they have also is heavily reference based aka parodies of different anime shows manga live stuff real world anime production and so on Anyhow comedyparody side of this franchise i absolutely love  Now nd side of this show is the serious dramas epic battle shounens and so on There are arcs that are fully comedy arcs that are fully serious and mixtures of both Serious side is usually quite dramatic and managed to somewhat tear me up now and then Whilst the action sequences are absolute bliss as well They are just presented in a really cool manner And extra points when sometime the add artistic element  Of course it has its sliceoflife side and pseudoromance Those are weaker side but aint the focus But when sometimes those are the focus then they are done in enjoyable method  To sum up overall gintamas I love the serious side and the silly side  Art and sound voice actingostoped is something I loved in all gintamas across the board They just click with me bliss to look at bliss to hear Music oped specifically are hyped up and upbeat which generally I dont like but gintama is the exception where I love them Art is cool sometimes artistic sometimes simple It has a bit of everything that makes it enjoyable And gore is absolutely satisfying as well well the blood to be specific  Well the serious side of stories in this anime are superb in my opinion or the overall idea of story that moves now and then But wouldnt say comedic side of series story is any worse  When at times comedy side has story Its usually quite enjoyable  Regarding characters I dont have much to say other than that variety stereotypes of offstereotypes is very large As well characters with depth but as well with oddity is as well in great selection Main team Gintoki the lazy dirty slob with superb second side of seriousness and caring about friendsallies Shinpachi the poor straightmanact sidekick who adds great value to the team Kagura the battle race girl that doesnt act like girl almost at all or in another words a dirty slob girl in a sense   Now to this season specific  I found it a bit disappointing Mainly because usually in gintama we have overly serious arcs or fully comedic whilst this one had a bit of mixture of both which somewhat ruined the experience Plus the artistic presentation felt this time around a bit lacking Maybe because of another studio who knows But anyhow it didnt feel as superb Rather than gintama it felt as watching just another good battle shounen anime in modern day with simplified animation  I mean it definitely was not any bad just didnt have the punch Gintama usually has Might be because it was short series maybe because it focused too much moving on with story Itll be shame to see it finalized in this manner  Rest I pretty much loved as usual in Gintama franchise',
#  'score_x': '8',
#  'scores': "{'Overall': '8', 'Story': '8', 'Animation': '8', 'Sound': '10', 'Character': '9', 'Enjoyment': '8'}",
#  'text len': '3229',
#  'uid_y': '34096',
#  'title': 'Gintama.',
#  'genre': "['Action', 'Comedy', 'Historical', 'Parody', 'Samurai', 'Sci-Fi', 'Shounen']",
#  'episodes': '12.0',
#  'members': '139309',
#  'popularity': '800',
#  'ranked': '15.0',
#  'score_y': '8.94'}

# %%
train_data, test_data = train_test_split(data, test_size=0.3, random_state=0)

# %%
# remove capitalization (and punctuation) and stopwords
stopwordSet = set(stopwords.words('english'))
wordCount = defaultdict(int)
punctuation = set(string.punctuation)
for d in train_data:
    r = ''.join([c for c in d['text'].lower() if not c in punctuation])
    ws = r.split()
    for w in ws:
        if not w in stopwordSet:
            wordCount[w] += 1

counts = [(wordCount[w], w) for w in wordCount]
counts.sort()
counts.reverse()

# %%
# 1000 most popular words (bag of words)
words = [x[1] for x in counts[:1000]]

# %%
wordId = dict(zip(words, range(len(words))))
wordSet = set(words)

# %%
# unigram
def featureUni(datum):
    feat = [0]*len(words)
    r = ''.join([c for c in datum['text'].lower() if not c in punctuation])
    for w in r.split():
        if w in wordSet and not w in stopwordSet:
            feat[wordId[w]] += 1
    #feat.append(int(datum['text len']))
    feat.append(1) # offset
    return feat

# %%
X = [featureUni(d) for d in data]
y = [d['score_x'] for d in data]

# %%
# 70/30 train/test split. convert y_data (scores) into ints
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
y_train = list(map(int, y_train))
y_test = list(map(int, y_test))

# %%
# Regularized regression
clf = linear_model.LogisticRegression(max_iter=100, multi_class='multinomial', fit_intercept=False, n_jobs=-1, verbose=2) # MSE + 1.0 l2
clf.fit(X_train, y_train)
theta = clf.coef_
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =        10010     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.10366D+05    |proj g|=  3.15509D+04
#  This problem is unconstrained.
# At iterate    1    f=  1.98308D+05    |proj g|=  1.73587D+04
#
# At iterate    2    f=  1.95484D+05    |proj g|=  1.43009D+04
#
# At iterate    3    f=  1.93704D+05    |proj g|=  7.42569D+03
#
# At iterate    4    f=  1.91773D+05    |proj g|=  9.00963D+03
#
# At iterate    5    f=  1.89343D+05    |proj g|=  1.24049D+04
#
# At iterate    6    f=  1.84950D+05    |proj g|=  1.39385D+04
#
# At iterate    7    f=  1.83499D+05    |proj g|=  4.99426D+04
#
# At iterate    8    f=  1.78823D+05    |proj g|=  1.45305D+04
#
# At iterate    9    f=  1.77188D+05    |proj g|=  1.22543D+04
#
# At iterate   10    f=  1.75668D+05    |proj g|=  1.90635D+04
#
# At iterate   11    f=  1.72548D+05    |proj g|=  2.54817D+04
#
# At iterate   12    f=  1.69573D+05    |proj g|=  1.48383D+04
#
# At iterate   13    f=  1.66957D+05    |proj g|=  1.65417D+04
#
# At iterate   14    f=  1.65412D+05    |proj g|=  5.65123D+03
#
# At iterate   15    f=  1.64727D+05    |proj g|=  6.37295D+03
#
# At iterate   16    f=  1.63529D+05    |proj g|=  9.82644D+03
#
# At iterate   17    f=  1.61919D+05    |proj g|=  1.24759D+04
#
# At iterate   18    f=  1.61795D+05    |proj g|=  2.37089D+04
#
# At iterate   19    f=  1.59130D+05    |proj g|=  8.31525D+03
#
# At iterate   20    f=  1.58433D+05    |proj g|=  4.80778D+03
#
# At iterate   21    f=  1.57952D+05    |proj g|=  4.67400D+03
#
# At iterate   22    f=  1.56931D+05    |proj g|=  5.87493D+03
#
# At iterate   23    f=  1.56013D+05    |proj g|=  6.79569D+03
#
# At iterate   24    f=  1.55081D+05    |proj g|=  5.65247D+03
#
# At iterate   25    f=  1.54355D+05    |proj g|=  5.18800D+03
#
# At iterate   26    f=  1.53992D+05    |proj g|=  6.27979D+03
#
# At iterate   27    f=  1.53530D+05    |proj g|=  4.12830D+03
#
# At iterate   28    f=  1.52738D+05    |proj g|=  3.63192D+03
#
# At iterate   29    f=  1.52067D+05    |proj g|=  4.36484D+03
#
# At iterate   30    f=  1.51765D+05    |proj g|=  9.74638D+03
#
# At iterate   31    f=  1.51151D+05    |proj g|=  4.11132D+03
#
# At iterate   32    f=  1.50949D+05    |proj g|=  3.11921D+03
#
# At iterate   33    f=  1.50603D+05    |proj g|=  4.77748D+03
#
# At iterate   34    f=  1.50106D+05    |proj g|=  3.59790D+03
#
# At iterate   35    f=  1.49866D+05    |proj g|=  6.34773D+03
#
# At iterate   36    f=  1.49381D+05    |proj g|=  3.47474D+03
#
# At iterate   37    f=  1.49058D+05    |proj g|=  3.98308D+03
#
# At iterate   38    f=  1.48756D+05    |proj g|=  3.68127D+03
#
# At iterate   39    f=  1.48330D+05    |proj g|=  2.64984D+03
#
# At iterate   40    f=  1.48116D+05    |proj g|=  4.67886D+03
#
# At iterate   41    f=  1.47788D+05    |proj g|=  2.63596D+03
#
# At iterate   42    f=  1.47623D+05    |proj g|=  2.08963D+03
#
# At iterate   43    f=  1.47414D+05    |proj g|=  4.24836D+03
#
# At iterate   44    f=  1.47249D+05    |proj g|=  6.13899D+03
#
# At iterate   45    f=  1.46998D+05    |proj g|=  3.17958D+03
#
# At iterate   46    f=  1.46732D+05    |proj g|=  3.58206D+03
#
# At iterate   47    f=  1.46608D+05    |proj g|=  2.52652D+03
#
# At iterate   48    f=  1.46335D+05    |proj g|=  5.85400D+03
#
# At iterate   49    f=  1.46055D+05    |proj g|=  4.55371D+03
#
# At iterate   50    f=  1.45905D+05    |proj g|=  3.45558D+03
#
# At iterate   51    f=  1.45629D+05    |proj g|=  2.24617D+03
#
# At iterate   52    f=  1.45540D+05    |proj g|=  5.89362D+03
#
# At iterate   53    f=  1.45307D+05    |proj g|=  2.50621D+03
#
# At iterate   54    f=  1.45181D+05    |proj g|=  1.90768D+03
#
# At iterate   55    f=  1.45058D+05    |proj g|=  2.59571D+03
#
# At iterate   56    f=  1.44873D+05    |proj g|=  4.22429D+03
#
# At iterate   57    f=  1.44714D+05    |proj g|=  4.50105D+03
#
# At iterate   58    f=  1.44586D+05    |proj g|=  2.88256D+03
#
# At iterate   59    f=  1.44507D+05    |proj g|=  1.66669D+03
#
# At iterate   60    f=  1.44438D+05    |proj g|=  1.96405D+03
#
# At iterate   61    f=  1.44207D+05    |proj g|=  3.14538D+03
#
# At iterate   62    f=  1.44092D+05    |proj g|=  2.32358D+03
#
# At iterate   63    f=  1.44005D+05    |proj g|=  2.41387D+03
#
# At iterate   64    f=  1.43917D+05    |proj g|=  2.13446D+03
#
# At iterate   65    f=  1.43834D+05    |proj g|=  1.95372D+03
#
# At iterate   66    f=  1.43690D+05    |proj g|=  2.60871D+03
#
# At iterate   67    f=  1.43505D+05    |proj g|=  2.94988D+03
#
# At iterate   68    f=  1.43437D+05    |proj g|=  2.98244D+03
#
# At iterate   69    f=  1.43361D+05    |proj g|=  2.03286D+03
#
# At iterate   70    f=  1.43313D+05    |proj g|=  1.54598D+03
#
# At iterate   71    f=  1.43215D+05    |proj g|=  2.53836D+03
#
# At iterate   72    f=  1.43115D+05    |proj g|=  2.66696D+03
#
# At iterate   73    f=  1.43034D+05    |proj g|=  1.80385D+03
#
# At iterate   74    f=  1.42950D+05    |proj g|=  1.56472D+03
#
# At iterate   75    f=  1.42886D+05    |proj g|=  3.47013D+03
#
# At iterate   76    f=  1.42829D+05    |proj g|=  2.67890D+03
#
# At iterate   77    f=  1.42688D+05    |proj g|=  2.31279D+03
#
# At iterate   78    f=  1.42661D+05    |proj g|=  3.42606D+03
#
# At iterate   79    f=  1.42603D+05    |proj g|=  1.29745D+03
#
# At iterate   80    f=  1.42571D+05    |proj g|=  1.45853D+03
#
# At iterate   81    f=  1.42534D+05    |proj g|=  1.22913D+03
#
# At iterate   82    f=  1.42475D+05    |proj g|=  1.58322D+03
#
# At iterate   83    f=  1.42423D+05    |proj g|=  2.70046D+03
#
# At iterate   84    f=  1.42352D+05    |proj g|=  2.43851D+03
#
# At iterate   85    f=  1.42315D+05    |proj g|=  1.59347D+03
#
# At iterate   86    f=  1.42283D+05    |proj g|=  1.46969D+03
#
# At iterate   87    f=  1.42248D+05    |proj g|=  1.35927D+03
#
# At iterate   88    f=  1.42198D+05    |proj g|=  2.29438D+03
#
# At iterate   89    f=  1.42141D+05    |proj g|=  1.61241D+03
#
# At iterate   90    f=  1.42113D+05    |proj g|=  1.18386D+03
#
# At iterate   91    f=  1.42070D+05    |proj g|=  1.07326D+03
#
# At iterate   92    f=  1.42020D+05    |proj g|=  1.74773D+03
#
# At iterate   93    f=  1.41960D+05    |proj g|=  3.59590D+03
#
# At iterate   94    f=  1.41883D+05    |proj g|=  1.74967D+03
#
# At iterate   95    f=  1.41853D+05    |proj g|=  1.01908D+03
#
# At iterate   96    f=  1.41831D+05    |proj g|=  2.09138D+03
#
# At iterate   97    f=  1.41800D+05    |proj g|=  1.85854D+03
#
# At iterate   98    f=  1.41763D+05    |proj g|=  1.26727D+03
#
# At iterate   99    f=  1.41708D+05    |proj g|=  1.32362D+03
#
# At iterate  100    f=  1.41665D+05    |proj g|=  1.44149D+03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
# 10010    100    107      1     0     0   1.441D+03   1.417D+05
#   F =   141665.01838022767
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:  2.7min finished

# %%
predictions = clf.predict(X_test)

# %%
def MSE(predictions, labels):
    differences = [(x-y)**2 for x,y in zip(predictions,labels)]
    return sum(differences) / len(differences)

# %%
wordSort = list(zip(theta[:-1], words))
#wordSort.sort()

# %%
# most "negative" unigrams
wordSort[:5]

# %%
# most "positive" unigrams
wordSort[-5:]

# %%
def accuracy(predictions, labels):
    correct = 0
    for i in range(len(predictions)):
        if predictions[i] == labels[i]:
            correct += 1
    return correct/len(labels)

# %%
# convert predictions (floats) to int and check accuracy
pred = clf.predict(X_train)
predictions = list(map(int, predictions))
print('train: ', accuracy(pred, y_train), MSE(pred, y_test))
print('test:', accuracy(predictions, y_test), MSE(predictions, y_test))
# Out:
# train:  0.3892689440789834 10.29259883542752
# test: 0.34291040964347735 3.373327204004495

# %%
print(metrics.classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.34      0.27      0.30       907
#            2       0.21      0.09      0.12       944
#            3       0.24      0.22      0.23      1744
#            4       0.20      0.10      0.14      1792
#            5       0.23      0.16      0.19      2599
#            6       0.25      0.22      0.24      3706
#            7       0.30      0.31      0.30      5731
#            8       0.31      0.34      0.32      7047
#            9       0.34      0.33      0.33      7343
#           10       0.48      0.65      0.55      7343
#
#     accuracy                           0.34     39156
#    macro avg       0.29      0.27      0.27     39156
# weighted avg       0.33      0.34      0.33     39156

# %% [markdown]
# ## naive baseline: predicting average irrespective of review text

# %%
mean_rating = numpy.mean(y_train)
mean_labels = [mean_rating]*len(y_train)
mean_labels_int = list(map(round, mean_labels))
print('train: ', accuracy(mean_labels_int, y_train), MSE(mean_labels, y_train))
mean_labels = [mean_rating]*len(y_test)
mean_labels_int = list(map(round, mean_labels))
print('test: ', accuracy(mean_labels_int, y_test), MSE(mean_labels, y_test))
# Out:
# train:  0.14593754446645724 5.3658626704794035
# test:  0.1463632648891613 5.440222819871951

# %% [markdown]
# ## ridge

# %%
m = linear_model.Ridge(1.0, fit_intercept=False)
m.fit(X_train, y_train)
p = m.predict(X_test)
print('test:', MSE(p, y_test))
p = list(map(round, p))
print(metrics.classification_report(y_test, p))
print(accuracy(p, y_test))
# Out:
# test: 3.3030332774471654
#               precision    recall  f1-score   support
#
#          -31       0.00      0.00      0.00         0
#          -20       0.00      0.00      0.00         0
#          -15       0.00      0.00      0.00         0
#          -12       0.00      0.00      0.00         0
#           -9       0.00      0.00      0.00         0
#           -8       0.00      0.00      0.00         0
#           -7       0.00      0.00      0.00         0
#           -6       0.00      0.00      0.00         0
#           -5       0.00      0.00      0.00         0
#           -4       0.00      0.00      0.00         0
#           -3       0.00      0.00      0.00         0
#           -2       0.00      0.00      0.00         0
#           -1       0.00      0.00      0.00         0
#            0       0.00      0.00      0.00         0
#            1       0.20      0.02      0.03       907
#            2       0.17      0.03      0.05       944
#            3       0.24      0.06      0.09      1744
#            4       0.16      0.07      0.10      1792
#            5       0.18      0.13      0.15      2599
#            6       0.19      0.23      0.21      3706
#            7       0.23      0.47      0.31      5731
#            8       0.24      0.45      0.32      7047
#            9       0.33      0.19      0.24      7343
#           10       0.47      0.08      0.13      7343
#           11       0.00      0.00      0.00         0
#           12       0.00      0.00      0.00         0
#           13       0.00      0.00      0.00         0
#           14       0.00      0.00      0.00         0
#           15       0.00      0.00      0.00         0
#           16       0.00      0.00      0.00         0
#           17       0.00      0.00      0.00         0
#           18       0.00      0.00      0.00         0
#           19       0.00      0.00      0.00         0
#
#     accuracy                           0.24     39156
#    macro avg       0.07      0.05      0.05     39156
# weighted avg       0.28      0.24      0.21     39156
#
# 0.23912044131167637
# /opt/conda/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## baseline: using review length

# %%
def get_len(d):
    feat = []
    feat.append(int(d['text len']))
    return feat
X_lengths = [get_len(d) for d in data]
X_len_train, X_len_test = train_test_split(X_lengths, test_size=0.3, random_state=0)
model = linear_model.LogisticRegression(n_jobs=-1)
model.fit(X_len_train, y_train)
y_len_train_pred = model.predict(X_len_train)
y_len_test_pred = model.predict(X_len_test)
print('train: ', accuracy(y_len_train_pred, y_train), MSE(y_len_train_pred, y_train))
print('test: ', accuracy(y_len_test_pred, y_test), MSE(y_len_test_pred, y_test))
# Out:
# train:  0.20423375400882215 10.065629754490429
# test:  0.20875472469097966 10.199254264991318

# %%
y_len_train_pred
# Out:
# array([ 9, 10, 10, ...,  8, 10, 10])

# %% [markdown]
# ## using tfidf instead of bag of words

# %%
from sklearn import metrics
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB, ComplementNB, BernoulliNB
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# %%
def text_process(reviewText):
    nopunc = [i for i in reviewText if i not in punctuation]
    nopunc_text = ''.join(nopunc)
    return [i.lower() for i in nopunc_text.split() if i.lower() not in stopwordSet]

# %%
X1 = [d['text'] for d in data]
y1 = [d['score_x'] for d in data]
y1 = list(map(int, y1))

# %%
# Benchmark model - multinomial logistic regression
pipeline = Pipeline([
    ('Tf-Idf', TfidfVectorizer(analyzer=text_process)),
    ('classifier', linear_model.LogisticRegression(max_iter=1000, n_jobs=-1, solver='newton-cg', class_weight='balanced'))
], verbose=True)
review_train1, review_test1, label_train1, label_test1 = train_test_split(X1, y1, test_size=0.3, random_state=0)
pipeline.fit(review_train1, label_train1)
pip_pred1 = pipeline.predict(review_test1)
print(metrics.classification_report(label_test1,pip_pred1))
# Out:
# [Pipeline] ............ (step 1 of 2) Processing Tf-Idf, total=  32.0s
# [Pipeline] ........ (step 2 of 2) Processing classifier, total= 2.1min
#               precision    recall  f1-score   support
#
#            1       0.28      0.44      0.34       907
#            2       0.16      0.23      0.19       944
#            3       0.21      0.25      0.23      1744
#            4       0.17      0.21      0.19      1792
#            5       0.21      0.22      0.21      2599
#            6       0.25      0.25      0.25      3706
#            7       0.31      0.28      0.30      5731
#            8       0.35      0.29      0.32      7047
#            9       0.38      0.34      0.36      7343
#           10       0.55      0.61      0.58      7343
#
#     accuracy                           0.35     39156
#    macro avg       0.29      0.31      0.30     39156
# weighted avg       0.35      0.35      0.35     39156

# %%
pip_pred1_train = pipeline.predict(review_train1)
print(metrics.classification_report(label_train1, pip_pred1_train))
print('train MSE: ', MSE(pip_pred1_train, label_train1))
print('test MSE: ', MSE(pip_pred1, label_test1))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.61      0.97      0.75      2009
#            2       0.65      0.95      0.78      2205
#            3       0.66      0.82      0.73      3982
#            4       0.62      0.78      0.69      4088
#            5       0.61      0.67      0.64      5949
#            6       0.60      0.59      0.59      8740
#            7       0.59      0.53      0.56     13333
#            8       0.60      0.50      0.55     16680
#            9       0.61      0.53      0.57     17200
#           10       0.66      0.73      0.69     17175
#
#     accuracy                           0.62     91361
#    macro avg       0.62      0.71      0.65     91361
# weighted avg       0.62      0.62      0.62     91361
#
# train MSE:  2.225741837326649
# test MSE:  3.3149708856880173

# %%
scores = cross_val_score(pipeline, X1, y1, n_jobs=-1, verbose=5)
print(scores.mean())
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  5.2min remaining:  7.7min
# 0.2930958586478101
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  6.0min finished
# [Pipeline] ............ (step 1 of 2) Processing Tf-Idf, total=  41.9s
# [Pipeline] ........ (step 2 of 2) Processing classifier, total= 4.1min
# [CV] END ................................ score: (test=0.322) total time= 5.0min
# [Pipeline] ............ (step 1 of 2) Processing Tf-Idf, total=  43.9s
# [Pipeline] ........ (step 2 of 2) Processing classifier, total= 4.2min
# [CV] END ................................ score: (test=0.313) total time= 5.1min
# [Pipeline] ............ (step 1 of 2) Processing Tf-Idf, total=  43.9s
# [Pipeline] ........ (step 2 of 2) Processing classifier, total= 4.3min
# [CV] END ................................ score: (test=0.284) total time= 5.2min
# [Pipeline] ............ (step 1 of 2) Processing Tf-Idf, total=  48.9s
# [Pipeline] ........ (step 2 of 2) Processing classifier, total= 4.9min
# [CV] END ................................ score: (test=0.272) total time= 5.8min
# [Pipeline] ............ (step 1 of 2) Processing Tf-Idf, total=  44.0s
# [Pipeline] ........ (step 2 of 2) Processing classifier, total= 5.0min
# [CV] END ................................ score: (test=0.274) total time= 5.9min

# %%
# First model try - Naive bayes
pipeline = Pipeline([
    ('Tf-Idf', TfidfVectorizer(analyzer=text_process)),
    ('classifier', ComplementNB())
], verbose=True)
review_train2, review_test2, label_train2, label_test2 = train_test_split(X1, y1, test_size=0.3, random_state=0)
pipeline.fit(review_train2, label_train2)
pip_pred2 = pipeline.predict(review_test2)
print(metrics.classification_report(label_test2, pip_pred2))
# Out:
# [Pipeline] ............ (step 1 of 2) Processing Tf-Idf, total=  29.7s
# [Pipeline] ........ (step 2 of 2) Processing classifier, total=   0.3s
#               precision    recall  f1-score   support
#
#            1       0.54      0.07      0.12       907
#            2       0.10      0.00      0.01       944
#            3       0.23      0.02      0.04      1744
#            4       0.12      0.00      0.01      1792
#            5       0.10      0.01      0.01      2599
#            6       0.12      0.02      0.03      3706
#            7       0.16      0.13      0.14      5731
#            8       0.22      0.37      0.28      7047
#            9       0.27      0.34      0.30      7343
#           10       0.40      0.67      0.50      7343
#
#     accuracy                           0.28     39156
#    macro avg       0.23      0.16      0.14     39156
# weighted avg       0.24      0.28      0.23     39156

# %%
MSE(pip_pred2, label_test2)
# Out:
# 6.1427878230667075

# %%
scores = cross_val_score(pipeline, X1, y1, n_jobs=-1, verbose=5)
print(scores.mean())
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# /opt/conda/lib/python3.9/site-packages/sklearn/model_selection/_split.py:666: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   58.9s remaining:  1.5min
# 0.20309703576635849
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  1.1min finished

# %%
# DecisionTreeClassifier
pipeline = Pipeline([
    ('Tf-Idf', TfidfVectorizer(analyzer=text_process)),
    ('classifier', DecisionTreeClassifier())
], verbose=True)
review_train3, review_test3, label_train3, label_test3 = train_test_split(X1, y1, test_size=0.3, random_state=0)
pipeline.fit(review_train3, label_train3)
pip_pred3 = pipeline.predict(review_test3)
print(metrics.classification_report(label_test3, pip_pred3))
# Out:
# [Pipeline] ............ (step 1 of 2) Processing Tf-Idf, total=  30.7s
# [Pipeline] ........ (step 2 of 2) Processing classifier, total=10.5min
#               precision    recall  f1-score   support
#
#            1       0.14      0.12      0.13       907
#            2       0.07      0.06      0.06       944
#            3       0.11      0.09      0.10      1744
#            4       0.09      0.09      0.09      1792
#            5       0.11      0.10      0.10      2599
#            6       0.12      0.11      0.12      3706
#            7       0.19      0.19      0.19      5731
#            8       0.20      0.22      0.21      7047
#            9       0.24      0.25      0.24      7343
#           10       0.35      0.36      0.36      7343
#
#     accuracy                           0.21     39156
#    macro avg       0.16      0.16      0.16     39156
# weighted avg       0.21      0.21      0.21     39156

# %%
MSE(pip_pred3, label_test3)
# Out:
# 7.109536214117887

# %%
scores = cross_val_score(pipeline, X1, y1, n_jobs=-1, verbose=5)
print(scores.mean())
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# /opt/conda/lib/python3.9/site-packages/sklearn/model_selection/_split.py:666: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed: 16.6min remaining: 24.8min
# 0.2121070000525629
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed: 19.3min finished

# %%
# RandomForest
pipeline = Pipeline([
    ('Tf-Idf', TfidfVectorizer(analyzer=text_process)),
    ('classifier', RandomForestClassifier(verbose=100, n_jobs=-1))
], verbose=True)
review_train4, review_test4, label_train4, label_test4 = train_test_split(X1, y1, test_size=0.3, random_state=0)
pipeline.fit(review_train4, label_train4)
pip_pred4 = pipeline.predict(review_test4)
print(metrics.classification_report(label_test4, pip_pred4))
# Out:
# [Pipeline] ............ (step 1 of 2) Processing Tf-Idf, total=  29.9s
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100[Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:   12.3s
#
# building tree 10 of 100[Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:   12.4s
#
# building tree 11 of 100[Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:   12.4s
#
# building tree 12 of 100[Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:   12.8s
#
# building tree 13 of 100[Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   13.0s
#
# building tree 14 of 100[Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:   13.1s
#
# building tree 15 of 100[Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:   13.2s
#
# building tree 16 of 100[Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:   13.2s
#
# building tree 17 of 100[Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   24.3s
#
# building tree 18 of 100[Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   24.5s
#
# building tree 19 of 100[Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:   24.6s
#
# building tree 20 of 100[Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:   24.9s
#
# building tree 21 of 100[Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:   25.4s
#
# building tree 22 of 100[Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:   25.6s
#
# building tree 23 of 100[Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:   25.7s
#
# building tree 24 of 100[Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   25.7s
#
# building tree 25 of 100[Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   36.6s
#
# building tree 26 of 100[Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:   36.8s
#
# building tree 27 of 100[Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:   37.3s
#
# building tree 28 of 100[Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:   37.4s
#
# building tree 29 of 100[Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:   37.7s
#
# building tree 30 of 100[Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:   38.0s
#
# building tree 31 of 100[Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:   38.1s
#
# building tree 32 of 100[Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   38.1s
#
# building tree 33 of 100[Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   49.1s
#
# building tree 34 of 100[Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   49.7s
#
# building tree 35 of 100[Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:   49.7s
#
# building tree 36 of 100[Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:   50.1s
#
# building tree 37 of 100[Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:   50.1s
#
# building tree 38 of 100[Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:   50.2s
#
# building tree 39 of 100[Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:   50.5s
#
# building tree 40 of 100[Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:   50.6s
#
# building tree 41 of 100[Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  1.0min
#
# building tree 42 of 100[Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.0min
#
# building tree 43 of 100[Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:  1.0min
#
# building tree 44 of 100[Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:  1.0min
#
# building tree 45 of 100[Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:  1.0min
#
# building tree 46 of 100[Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:  1.0min
#
# building tree 47 of 100[Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:  1.0min
#
# building tree 48 of 100[Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:  1.0min
#
# building tree 49 of 100[Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:  1.2min
#
# building tree 50 of 100[Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.2min
#
# building tree 51 of 100[Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:  1.2min
#
# building tree 52 of 100[Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:  1.2min
#
# building tree 53 of 100[Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:  1.2min
#
# building tree 54 of 100[Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:  1.2min
#
# building tree 55 of 100[Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:  1.3min
#
# building tree 56 of 100[Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:  1.3min
#
# building tree 57 of 100[Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:  1.4min
#
# building tree 58 of 100[Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:  1.4min
#
# building tree 59 of 100[Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:  1.4min
#
# building tree 60 of 100
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:  1.4min
# building tree 61 of 100[Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  1.4min
#
# building tree 62 of 100[Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:  1.4min
#
# building tree 63 of 100[Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:  1.5min
#
# building tree 64 of 100[Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:  1.5min
#
# building tree 65 of 100[Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:  1.6min
#
# building tree 66 of 100[Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:  1.6min
#
# building tree 67 of 100[Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed:  1.6min
#
# building tree 68 of 100[Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:  1.7min
#
# building tree 69 of 100[Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:  1.7min
#
# building tree 70 of 100[Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:  1.7min
#
# building tree 71 of 100[Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed:  1.7min
#
# building tree 72 of 100[Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  1.7min
#
# building tree 73 of 100[Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:  1.8min
#
# building tree 74 of 100[Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:  1.8min
#
# building tree 75 of 100[Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed:  1.8min
#
# building tree 76 of 100[Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:  1.8min
#
# building tree 77 of 100[Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:  1.8min
#
# building tree 78 of 100[Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed:  1.9min
#
# building tree 79 of 100[Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed:  1.9min
#
# building tree 80 of 100[Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed:  1.9min
#
# building tree 81 of 100[Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:  2.0min
#
# building tree 82 of 100[Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:  2.0min
#
# building tree 83 of 100[Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed:  2.0min
#
# building tree 84 of 100[Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:  2.0min
#
# building tree 85 of 100[Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:  2.0min
#
# building tree 86 of 100[Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed:  2.1min
#
# building tree 87 of 100[Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed:  2.1min
#
# building tree 88 of 100[Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:  2.1min
#
# building tree 89 of 100[Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:  2.2min
#
# building tree 90 of 100[Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:  2.2min
#
# building tree 91 of 100[Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed:  2.2min
#
# building tree 92 of 100[Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed:  2.2min
#
# building tree 93 of 100[Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed:  2.2min
#
# building tree 94 of 100
# building tree 95 of 100[Parallel(n_jobs=-1)]: Done  87 out of 100 | elapsed:  2.3min remaining:   20.2s
#
# building tree 96 of 100
# building tree 97 of 100[Parallel(n_jobs=-1)]: Done  89 out of 100 | elapsed:  2.4min remaining:   17.9s
#
# building tree 98 of 100
# building tree 99 of 100[Parallel(n_jobs=-1)]: Done  91 out of 100 | elapsed:  2.4min remaining:   14.4s
#
# building tree 100 of 100
# [Parallel(n_jobs=-1)]: Done  93 out of 100 | elapsed:  2.4min remaining:   11.0s
# [Parallel(n_jobs=-1)]: Done  95 out of 100 | elapsed:  2.5min remaining:    7.8s
# [Parallel(n_jobs=-1)]: Done  97 out of 100 | elapsed:  2.6min remaining:    4.8s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  2.6min finished
# [Pipeline] ........ (step 2 of 2) Processing classifier, total= 2.6min
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done   1 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done   2 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done   3 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done   4 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done   5 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done   6 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done   7 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done   8 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done   9 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done  10 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done  11 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done  12 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done  13 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done  14 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done  15 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done  16 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done  17 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done  18 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done  19 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done  20 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done  21 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done  22 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done  23 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done  24 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done  25 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done  26 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done  27 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done  28 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done  29 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done  30 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done  31 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done  32 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=8)]: Done  33 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done  35 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done  36 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done  37 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done  38 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done  39 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done  40 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done  41 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done  42 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done  43 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done  44 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done  45 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done  46 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done  47 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done  48 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done  49 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=8)]: Done  50 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done  51 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done  52 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done  53 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done  54 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done  55 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done  56 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done  57 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done  58 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done  59 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done  60 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done  61 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done  62 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done  63 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done  64 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done  65 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done  66 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done  67 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done  68 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done  69 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done  70 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done  71 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done  72 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done  73 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done  74 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done  75 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done  76 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done  77 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done  78 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done  79 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done  80 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done  81 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done  82 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done  83 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done  84 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=8)]: Done  85 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done  87 out of 100 | elapsed:    1.1s remaining:    0.2s
# [Parallel(n_jobs=8)]: Done  89 out of 100 | elapsed:    1.1s remaining:    0.1s
# [Parallel(n_jobs=8)]: Done  91 out of 100 | elapsed:    1.1s remaining:    0.1s
# [Parallel(n_jobs=8)]: Done  93 out of 100 | elapsed:    1.2s remaining:    0.1s
# [Parallel(n_jobs=8)]: Done  95 out of 100 | elapsed:    1.2s remaining:    0.1s
# [Parallel(n_jobs=8)]: Done  97 out of 100 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=8)]: Done 100 out of 100 | elapsed:    1.2s finished
#               precision    recall  f1-score   support
#
#            1       0.67      0.01      0.01       907
#            2       0.00      0.00      0.00       944
#            3       0.29      0.01      0.02      1744
#            4       0.17      0.00      0.01      1792
#            5       0.12      0.00      0.01      2599
#            6       0.14      0.03      0.04      3706
#            7       0.20      0.17      0.19      5731
#            8       0.22      0.35      0.27      7047
#            9       0.23      0.28      0.26      7343
#           10       0.36      0.65      0.47      7343
#
#     accuracy                           0.27     39156
#    macro avg       0.24      0.15      0.13     39156
# weighted avg       0.24      0.27      0.22     39156

# %%
MSE(pip_pred4, label_test4)
# Out:
# 6.758836449075493

# %%
scores = cross_val_score(pipeline, X1, y1, n_jobs=-1, verbose=5)
print(scores.mean())
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# /opt/conda/lib/python3.9/site-packages/sklearn/model_selection/_split.py:666: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
# [Pipeline] ............ (step 1 of 2) Processing Tf-Idf, total=  46.9s
# [Pipeline] ........ (step 2 of 2) Processing classifier, total=18.3min
# [CV] END ................................ score: (test=0.206) total time=19.2min
# [Pipeline] ............ (step 1 of 2) Processing Tf-Idf, total=  41.6s
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:  2.5min
# building tree 10 of 100
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:  2.5min
# building tree 11 of 100
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:  2.5min
# building tree 12 of 100
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:  2.6min
# building tree 13 of 100
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:  2.6min
# building tree 14 of 100
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:  2.7min
# building tree 15 of 100
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:  2.8min
# building tree 16 of 100
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:  2.8min
# building tree 17 of 100
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:  6.1min
# building tree 18 of 100
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:  6.3min
# building tree 19 of 100
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:  6.5min
# building tree 20 of 100
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:  6.5min
# building tree 21 of 100
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:  6.6min
# building tree 22 of 100
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:  6.6min
# building tree 23 of 100
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:  6.7min
# building tree 24 of 100
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:  7.0min
# building tree 25 of 100
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  9.9min
# building tree 26 of 100
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed: 10.3min
# building tree 27 of 100
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed: 10.4min
# building tree 28 of 100
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed: 10.6min
# building tree 29 of 100
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed: 10.6min
# building tree 30 of 100
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed: 10.7min
# building tree 31 of 100
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed: 10.9min
# building tree 32 of 100
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed: 11.2min
# building tree 33 of 100
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed: 13.9min
# building tree 34 of 100
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed: 14.1min
# building tree 35 of 100
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed: 14.2min
# building tree 36 of 100
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed: 14.3min
# building tree 37 of 100
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed: 14.6min
# building tree 38 of 100
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed: 14.6min
# building tree 39 of 100
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed: 14.8min
# building tree 40 of 100
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed: 15.0min
# building tree 41 of 100
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed: 17.7min
# building tree 42 of 100
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed: 18.1min
# building tree 43 of 100
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed: 18.3min
# building tree 44 of 100
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed: 18.3min
# building tree 45 of 100
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed: 18.4min
# building tree 46 of 100
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed: 18.6min
# building tree 47 of 100
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed: 18.6min
# building tree 48 of 100
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed: 18.9min
# building tree 49 of 100
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed: 21.6min
# building tree 50 of 100
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 22.0min
# building tree 51 of 100
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed: 22.1min
# building tree 52 of 100
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed: 22.2min
# building tree 53 of 100
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed: 22.4min
# building tree 54 of 100
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed: 22.5min
# building tree 55 of 100
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed: 22.6min
# building tree 56 of 100
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed: 23.1min
# building tree 57 of 100
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed: 25.4min
# building tree 58 of 100
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed: 25.9min
# building tree 59 of 100
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed: 26.1min
# building tree 60 of 100
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed: 26.1min
# building tree 61 of 100
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed: 26.2min
# building tree 62 of 100
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed: 26.2min
# building tree 63 of 100
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed: 26.7min
# building tree 64 of 100
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed: 27.1min
# building tree 65 of 100
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed: 29.6min
# building tree 66 of 100
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed: 30.1min
# building tree 67 of 100
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed: 30.1min
# building tree 68 of 100
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed: 30.3min
# building tree 69 of 100
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed: 30.5min
# building tree 70 of 100
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed: 30.5min
# building tree 71 of 100
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed: 30.9min
# building tree 72 of 100
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed: 31.0min
# building tree 73 of 100
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed: 33.7min
# building tree 74 of 100
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed: 34.1min
# building tree 75 of 100
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed: 34.2min
# building tree 76 of 100
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed: 34.3min
# building tree 77 of 100
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed: 34.6min
# building tree 78 of 100
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed: 34.7min
# building tree 79 of 100
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed: 35.0min
# building tree 80 of 100
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed: 35.1min
# building tree 81 of 100
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed: 37.5min
# building tree 82 of 100
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed: 37.9min
# building tree 83 of 100
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed: 38.1min
# building tree 84 of 100
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed: 38.2min
# building tree 85 of 100
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed: 38.6min
# building tree 86 of 100
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed: 38.7min
# building tree 87 of 100
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed: 38.8min
# building tree 88 of 100
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed: 39.3min
# building tree 89 of 100
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed: 41.5min
# building tree 90 of 100
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed: 41.7min
# building tree 91 of 100
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed: 42.1min
# building tree 92 of 100
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed: 42.3min
# building tree 93 of 100
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed: 42.5min
# building tree 94 of 100
# building tree 95 of 100
# [Parallel(n_jobs=-1)]: Done  87 out of 100 | elapsed: 42.7min remaining:  6.4min
# building tree 96 of 100
# building tree 97 of 100
# [Parallel(n_jobs=-1)]: Done  89 out of 100 | elapsed: 45.5min remaining:  5.6min
# building tree 98 of 100
# building tree 99 of 100
# [Pipeline] ............ (step 1 of 2) Processing Tf-Idf, total=  52.1s
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# building tree 1 of 100
# building tree 2 of 100
# building tree 3 of 100
# building tree 4 of 100
# building tree 5 of 100
# building tree 6 of 100
# building tree 7 of 100
# building tree 8 of 100
# building tree 9 of 100
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:  3.6min
# building tree 10 of 100
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:  3.6min
# building tree 11 of 100
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:  3.6min
# building tree 12 of 100
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:  3.7min
# building tree 13 of 100
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:  3.7min
# building tree 14 of 100
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:  3.8min
# building tree 15 of 100
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:  3.8min
# building tree 16 of 100
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:  3.9min
# building tree 17 of 100
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:  7.3min
# building tree 18 of 100
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:  7.6min
# building tree 19 of 100
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:  7.6min
# building tree 20 of 100
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:  7.7min
# building tree 21 of 100
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:  7.7min
# building tree 22 of 100
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:  7.7min
# building tree 23 of 100
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:  7.8min
# building tree 24 of 100
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed: 11.3min
# building tree 25 of 100
# building tree 26 of 100
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed: 11.5min
# building tree 27 of 100
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed: 11.5min
# building tree 28 of 100
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed: 11.6min
# building tree 29 of 100
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed: 11.7min
# building tree 30 of 100
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed: 11.7min
# building tree 31 of 100
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed: 11.9min
# building tree 32 of 100
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed: 11.9min
# building tree 33 of 100
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed: 15.2min
# building tree 34 of 100
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed: 15.4min
# building tree 35 of 100
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed: 15.4min
# building tree 36 of 100
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed: 15.4min
# building tree 37 of 100
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed: 15.6min
# building tree 38 of 100
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed: 15.6min
# building tree 39 of 100
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed: 15.6min
# building tree 40 of 100
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed: 15.7min
# building tree 41 of 100
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed: 19.1min
# building tree 42 of 100
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed: 19.1min
# building tree 43 of 100
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed: 19.3min
# building tree 44 of 100
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed: 19.3min
# building tree 45 of 100
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed: 19.4min
# building tree 46 of 100
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed: 19.4min
# building tree 47 of 100
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed: 19.4min
# building tree 48 of 100
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed: 19.6min
# building tree 49 of 100
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed: 22.8min
# building tree 50 of 100
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 23.0min
# building tree 51 of 100
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed: 23.1min
# building tree 52 of 100
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed: 23.3min
# building tree 53 of 100
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed: 23.4min
# building tree 54 of 100
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed: 23.4min
# building tree 55 of 100
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed: 23.4min
# building tree 56 of 100
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed: 23.5min
# building tree 57 of 100
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed: 26.9min
# building tree 58 of 100
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed: 27.0min
# building tree 59 of 100
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed: 27.2min
# building tree 60 of 100
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed: 27.2min
# building tree 61 of 100
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed: 27.3min
# building tree 62 of 100
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed: 27.4min
# building tree 63 of 100
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed: 27.4min
# building tree 64 of 100
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed: 27.4min
# building tree 65 of 100
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed: 30.7min
# building tree 66 of 100
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed: 30.9min
# building tree 67 of 100
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed: 31.1min
# building tree 68 of 100
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed: 31.2min
# building tree 69 of 100
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed: 31.4min
# building tree 70 of 100
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed: 31.4min
# building tree 71 of 100
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed: 31.5min
# building tree 72 of 100
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed: 31.6min
# building tree 73 of 100
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed: 34.8min
# building tree 74 of 100
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed: 34.8min
# building tree 75 of 100
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed: 35.0min
# building tree 76 of 100
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed: 35.0min
# building tree 77 of 100
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed: 35.0min
# building tree 78 of 100
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed: 35.4min
# building tree 79 of 100
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed: 35.6min
# building tree 80 of 100
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed: 35.7min
# building tree 81 of 100
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed: 38.6min
# building tree 82 of 100
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed: 38.6min
# building tree 83 of 100
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed: 38.8min
# building tree 84 of 100
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed: 38.9min
# building tree 85 of 100
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed: 38.9min
# building tree 86 of 100
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed: 39.2min
# building tree 87 of 100
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed: 39.5min
# building tree 88 of 100
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed: 39.7min
# building tree 89 of 100
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed: 42.7min
# building tree 90 of 100
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed: 42.7min
# building tree 91 of 100
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed: 42.7min
# building tree 92 of 100
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed: 42.8min
# building tree 93 of 100
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed: 42.9min
# building tree 94 of 100
# building tree 95 of 100
# [Parallel(n_jobs=-1)]: Done  87 out of 100 | elapsed: 43.4min remaining:  6.5min
# building tree 96 of 100
# building tree 97 of 100
# [Parallel(n_jobs=-1)]: Done  89 out of 100 | elapsed: 46.5min remaining:  5.7min
# building tree 98 of 100
# building tree 99 of 100
# [Parallel(n_jobs=-1)]: Done  91 out of 100 | elapsed: 46.6min remaining:  4.6min
# building tree 100 of 100
# [Parallel(n_jobs=-1)]: Done  93 out of 100 | elapsed: 46.8min remaining:  3.5min
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed: 49.0min remaining: 73.5min
# ---------------------------------------------------------------------------
# TerminatedWorkerError                     Traceback (most recent call last)
# /tmp/ipykernel_440/1396780024.py in <module>
# ----> 1 scores = cross_val_score(pipeline, X1, y1, n_jobs=-1, verbose=5)
#       2 print(scores.mean())
#
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /opt/conda/lib/python3.9/site-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     443     scorer = check_scoring(estimator, scoring=scoring)
#     444
# --> 445     cv_results = cross_validate(estimator=estimator, X=X, y=y, groups=groups,
#     446                                 scoring={'score': scorer}, cv=cv,
#     447                                 n_jobs=n_jobs, verbose=verbose,
#
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /opt/conda/lib/python3.9/site-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     248     parallel = Parallel(n_jobs=n_jobs, verbose=verbose,
#     249                         pre_dispatch=pre_dispatch)
# --> 250     results = parallel(
#     251         delayed(_fit_and_score)(
#     252             clone(estimator), X, y, scorers, train, test, verbose, None,
#
# /opt/conda/lib/python3.9/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1052
#    1053             with self._backend.retrieval_context():
# -> 1054                 self.retrieve()
#    1055             # Make sure that we get a last message telling us we are done
#    1056             elapsed_time = time.time() - self._start_time
#
# /opt/conda/lib/python3.9/site-packages/joblib/parallel.py in retrieve(self)
#     931             try:
#     932                 if getattr(self._backend, 'supports_timeout', False):
# --> 933                     self._output.extend(job.get(timeout=self.timeout))
#     934                 else:
#     935                     self._output.extend(job.get())
#
# /opt/conda/lib/python3.9/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# /opt/conda/lib/python3.9/concurrent/futures/_base.py in result(self, timeout)
#     443                     raise CancelledError()
#     444                 elif self._state == FINISHED:
# --> 445                     return self.__get_result()
#     446                 else:
#     447                     raise TimeoutError()
#
# /opt/conda/lib/python3.9/concurrent/futures/_base.py in __get_result(self)
#     388         if self._exception:
#     389             try:
# --> 390                 raise self._exception
#     391             finally:
#     392                 # Break a reference cycle with the exception in self._exception
#
# TerminatedWorkerError: A worker process managed by the executor was unexpectedly terminated. This could be caused by a segmentation fault while calling the function or by an excessive memory usage causing the Operating System to kill the worker.
#
# The exit codes of the workers are {SIGKILL(-9)}

# %% [markdown]
# ## removing pipeline
